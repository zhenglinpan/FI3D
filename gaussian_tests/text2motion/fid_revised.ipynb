# %% [markdown]
# ### Make sure you have saved the featuremaps(activations) to npy files

# %%
import numpy as np
from scipy import linalg

fake = np.load(r'fake_emb.npy')
real = np.load(r'gt_emb.npy')

print(f'shape of fake: {fake.shape}')
print(f'shape of real: {real.shape}')

assert len(fake.shape) == 2
# Out:
# shape of fake: (4640, 512)
# shape of real: (4640, 512)

# %% [markdown]
# ### for some reason, the featuremaps might contain nan values, so we need to remove them
# Here we remove by the row

# %%
remov_rows = []

if np.isnan(real).any():
    for i in range(real.shape[0]):
        for j in range(real.shape[1]):
            if np.isnan(real[i][j]):
                # print(i, j)
                remov_rows.append(i)
                break
real_safe = np.delete(real, remov_rows, axis=0)
print('Is there any nan left in the featuremap?', np.isnan(real_safe).any())

remov_rows = []
if np.isnan(fake).any():
    for i in range(real.shape[0]):
        for j in range(real.shape[1]):
            if np.isnan(fake[i][j]):
                # print(i, j)
                remov_rows.append(i)
                break
fake_safe = np.delete(fake, remov_rows, axis=0)
print('Is there any nan left in the featuremap?', np.isnan(fake_safe).any())
# Out:
# Is there any nan left in the featuremap? False
# Is there any nan left in the featuremap? False

# %% [markdown]
# ### Hypothsis Tests

# %%
# shapiro-wilk test
# null hypothesis: the sample is drawn from a normal distribution
# once sample amount is more than 5000, shapiro-wilk test will be not reliable

import scipy

for i in range(real_safe.shape[1]):
    x = real_safe[:, i]
    if scipy.stats.shapiro(x).pvalue < 0.05:
        print(f'{i}th dimension of ground truth motion featuremap is not normal distributed')

for i in range(fake_safe.shape[1]):
    x = fake_safe[:, i]
    if scipy.stats.shapiro(x).pvalue < 0.05:
        print(f'{i}th dimension of generated motion featuremap is not normal distributed')
# Out:
# 0th dimension of ground truth motion featuremap is not normal distributed
# 1th dimension of ground truth motion featuremap is not normal distributed
# 2th dimension of ground truth motion featuremap is not normal distributed
# 3th dimension of ground truth motion featuremap is not normal distributed
# 4th dimension of ground truth motion featuremap is not normal distributed
# 5th dimension of ground truth motion featuremap is not normal distributed
# 6th dimension of ground truth motion featuremap is not normal distributed
# 7th dimension of ground truth motion featuremap is not normal distributed
# 8th dimension of ground truth motion featuremap is not normal distributed
# 9th dimension of ground truth motion featuremap is not normal distributed
# 10th dimension of ground truth motion featuremap is not normal distributed
# 11th dimension of ground truth motion featuremap is not normal distributed
# 12th dimension of ground truth motion featuremap is not normal distributed
# 13th dimension of ground truth motion featuremap is not normal distributed
# 14th dimension of ground truth motion featuremap is not normal distributed
# 15th dimension of ground truth motion featuremap is not normal distributed
# 16th dimension of ground truth motion featuremap is not normal distributed
# 17th dimension of ground truth motion featuremap is not normal distributed
# 18th dimension of ground truth motion featuremap is not normal distributed
# 19th dimension of ground truth motion featuremap is not normal distributed
# 20th dimension of ground truth motion featuremap is not normal distributed
# 21th dimension of ground truth motion featuremap is not normal distributed
# 22th dimension of ground truth motion featuremap is not normal distributed
# 23th dimension of ground truth motion featuremap is not normal distributed
# 24th dimension of ground truth motion featuremap is not normal distributed
# 25th dimension of ground truth motion featuremap is not normal distributed
# 26th dimension of ground truth motion featuremap is not normal distributed
# 27th dimension of ground truth motion featuremap is not normal distributed
# 28th dimension of ground truth motion featuremap is not normal distributed
# 29th dimension of ground truth motion featuremap is not normal distributed
# 30th dimension of ground truth motion featuremap is not normal distributed
# 31th dimension of ground truth motion featuremap is not normal distributed
# 32th dimension of ground truth motion featuremap is not normal distributed
# 33th dimension of ground truth motion featuremap is not normal distributed
# 34th dimension of ground truth motion featuremap is not normal distributed
# 35th dimension of ground truth motion featuremap is not normal distributed
# 36th dimension of ground truth motion featuremap is not normal distributed
# 37th dimension of ground truth motion featuremap is not normal distributed
# 38th dimension of ground truth motion featuremap is not normal distributed
# 39th dimension of ground truth motion featuremap is not normal distributed
# 40th dimension of ground truth motion featuremap is not normal distributed
# 41th dimension of ground truth motion featuremap is not normal distributed
# 42th dimension of ground truth motion featuremap is not normal distributed
# 43th dimension of ground truth motion featuremap is not normal distributed
# 44th dimension of ground truth motion featuremap is not normal distributed
# 45th dimension of ground truth motion featuremap is not normal distributed
# 46th dimension of ground truth motion featuremap is not normal distributed
# 47th dimension of ground truth motion featuremap is not normal distributed
# 48th dimension of ground truth motion featuremap is not normal distributed
# 49th dimension of ground truth motion featuremap is not normal distributed
# 50th dimension of ground truth motion featuremap is not normal distributed
# 51th dimension of ground truth motion featuremap is not normal distributed
# 52th dimension of ground truth motion featuremap is not normal distributed
# 53th dimension of ground truth motion featuremap is not normal distributed
# 54th dimension of ground truth motion featuremap is not normal distributed
# 55th dimension of ground truth motion featuremap is not normal distributed
# 56th dimension of ground truth motion featuremap is not normal distributed
# 57th dimension of ground truth motion featuremap is not normal distributed
# 58th dimension of ground truth motion featuremap is not normal distributed
# 59th dimension of ground truth motion featuremap is not normal distributed
# 60th dimension of ground truth motion featuremap is not normal distributed
# 61th dimension of ground truth motion featuremap is not normal distributed
# 62th dimension of ground truth motion featuremap is not normal distributed
# 63th dimension of ground truth motion featuremap is not normal distributed
# 64th dimension of ground truth motion featuremap is not normal distributed
# 65th dimension of ground truth motion featuremap is not normal distributed
# 66th dimension of ground truth motion featuremap is not normal distributed
# 67th dimension of ground truth motion featuremap is not normal distributed
# 68th dimension of ground truth motion featuremap is not normal distributed
# 69th dimension of ground truth motion featuremap is not normal distributed
# 70th dimension of ground truth motion featuremap is not normal distributed
# 71th dimension of ground truth motion featuremap is not normal distributed
# 72th dimension of ground truth motion featuremap is not normal distributed
# 73th dimension of ground truth motion featuremap is not normal distributed
# 74th dimension of ground truth motion featuremap is not normal distributed
# 75th dimension of ground truth motion featuremap is not normal distributed
# 76th dimension of ground truth motion featuremap is not normal distributed
# 77th dimension of ground truth motion featuremap is not normal distributed
# 78th dimension of ground truth motion featuremap is not normal distributed
# 79th dimension of ground truth motion featuremap is not normal distributed
# 80th dimension of ground truth motion featuremap is not normal distributed
# 81th dimension of ground truth motion featuremap is not normal distributed
# 82th dimension of ground truth motion featuremap is not normal distributed
# 83th dimension of ground truth motion featuremap is not normal distributed
# 84th dimension of ground truth motion featuremap is not normal distributed
# 85th dimension of ground truth motion featuremap is not normal distributed
# 86th dimension of ground truth motion featuremap is not normal distributed
# 87th dimension of ground truth motion featuremap is not normal distributed
# 88th dimension of ground truth motion featuremap is not normal distributed
# 89th dimension of ground truth motion featuremap is not normal distributed
# 90th dimension of ground truth motion featuremap is not normal distributed
# 91th dimension of ground truth motion featuremap is not normal distributed
# 92th dimension of ground truth motion featuremap is not normal distributed
# 93th dimension of ground truth motion featuremap is not normal distributed
# 94th dimension of ground truth motion featuremap is not normal distributed
# 95th dimension of ground truth motion featuremap is not normal distributed
# 96th dimension of ground truth motion featuremap is not normal distributed
# 97th dimension of ground truth motion featuremap is not normal distributed
# 98th dimension of ground truth motion featuremap is not normal distributed
# 99th dimension of ground truth motion featuremap is not normal distributed
# 100th dimension of ground truth motion featuremap is not normal distributed
# 101th dimension of ground truth motion featuremap is not normal distributed
# 102th dimension of ground truth motion featuremap is not normal distributed
# 103th dimension of ground truth motion featuremap is not normal distributed
# 104th dimension of ground truth motion featuremap is not normal distributed
# 105th dimension of ground truth motion featuremap is not normal distributed
# 106th dimension of ground truth motion featuremap is not normal distributed
# 107th dimension of ground truth motion featuremap is not normal distributed
# 108th dimension of ground truth motion featuremap is not normal distributed
# 109th dimension of ground truth motion featuremap is not normal distributed
# 110th dimension of ground truth motion featuremap is not normal distributed
# 111th dimension of ground truth motion featuremap is not normal distributed
# 112th dimension of ground truth motion featuremap is not normal distributed
# 113th dimension of ground truth motion featuremap is not normal distributed
# 114th dimension of ground truth motion featuremap is not normal distributed
# 115th dimension of ground truth motion featuremap is not normal distributed
# 116th dimension of ground truth motion featuremap is not normal distributed
# 117th dimension of ground truth motion featuremap is not normal distributed
# 118th dimension of ground truth motion featuremap is not normal distributed
# 119th dimension of ground truth motion featuremap is not normal distributed
# 120th dimension of ground truth motion featuremap is not normal distributed
# 121th dimension of ground truth motion featuremap is not normal distributed
# 122th dimension of ground truth motion featuremap is not normal distributed
# 123th dimension of ground truth motion featuremap is not normal distributed
# 124th dimension of ground truth motion featuremap is not normal distributed
# 125th dimension of ground truth motion featuremap is not normal distributed
# 126th dimension of ground truth motion featuremap is not normal distributed
# 127th dimension of ground truth motion featuremap is not normal distributed
# 128th dimension of ground truth motion featuremap is not normal distributed
# 129th dimension of ground truth motion featuremap is not normal distributed
# 130th dimension of ground truth motion featuremap is not normal distributed
# 131th dimension of ground truth motion featuremap is not normal distributed
# 132th dimension of ground truth motion featuremap is not normal distributed
# 133th dimension of ground truth motion featuremap is not normal distributed
# 134th dimension of ground truth motion featuremap is not normal distributed
# 135th dimension of ground truth motion featuremap is not normal distributed
# 136th dimension of ground truth motion featuremap is not normal distributed
# 137th dimension of ground truth motion featuremap is not normal distributed
# 138th dimension of ground truth motion featuremap is not normal distributed
# 139th dimension of ground truth motion featuremap is not normal distributed
# 140th dimension of ground truth motion featuremap is not normal distributed
# 141th dimension of ground truth motion featuremap is not normal distributed
# 142th dimension of ground truth motion featuremap is not normal distributed
# 143th dimension of ground truth motion featuremap is not normal distributed
# 144th dimension of ground truth motion featuremap is not normal distributed
# 145th dimension of ground truth motion featuremap is not normal distributed
# 146th dimension of ground truth motion featuremap is not normal distributed
# 147th dimension of ground truth motion featuremap is not normal distributed
# 148th dimension of ground truth motion featuremap is not normal distributed
# 149th dimension of ground truth motion featuremap is not normal distributed
# 150th dimension of ground truth motion featuremap is not normal distributed
# 151th dimension of ground truth motion featuremap is not normal distributed
# 152th dimension of ground truth motion featuremap is not normal distributed
# 153th dimension of ground truth motion featuremap is not normal distributed
# 154th dimension of ground truth motion featuremap is not normal distributed
# 155th dimension of ground truth motion featuremap is not normal distributed
# 156th dimension of ground truth motion featuremap is not normal distributed
# 157th dimension of ground truth motion featuremap is not normal distributed
# 158th dimension of ground truth motion featuremap is not normal distributed
# 159th dimension of ground truth motion featuremap is not normal distributed
# 160th dimension of ground truth motion featuremap is not normal distributed
# 161th dimension of ground truth motion featuremap is not normal distributed
# 162th dimension of ground truth motion featuremap is not normal distributed
# 163th dimension of ground truth motion featuremap is not normal distributed
# 164th dimension of ground truth motion featuremap is not normal distributed
# 165th dimension of ground truth motion featuremap is not normal distributed
# 166th dimension of ground truth motion featuremap is not normal distributed
# 167th dimension of ground truth motion featuremap is not normal distributed
# 168th dimension of ground truth motion featuremap is not normal distributed
# 169th dimension of ground truth motion featuremap is not normal distributed
# 170th dimension of ground truth motion featuremap is not normal distributed
# 171th dimension of ground truth motion featuremap is not normal distributed
# 172th dimension of ground truth motion featuremap is not normal distributed
# 173th dimension of ground truth motion featuremap is not normal distributed
# 174th dimension of ground truth motion featuremap is not normal distributed
# 175th dimension of ground truth motion featuremap is not normal distributed
# 176th dimension of ground truth motion featuremap is not normal distributed
# 177th dimension of ground truth motion featuremap is not normal distributed
# 178th dimension of ground truth motion featuremap is not normal distributed
# 179th dimension of ground truth motion featuremap is not normal distributed
# 180th dimension of ground truth motion featuremap is not normal distributed
# 181th dimension of ground truth motion featuremap is not normal distributed
# 182th dimension of ground truth motion featuremap is not normal distributed
# 183th dimension of ground truth motion featuremap is not normal distributed
# 184th dimension of ground truth motion featuremap is not normal distributed
# 185th dimension of ground truth motion featuremap is not normal distributed
# 186th dimension of ground truth motion featuremap is not normal distributed
# 187th dimension of ground truth motion featuremap is not normal distributed
# 188th dimension of ground truth motion featuremap is not normal distributed
# 189th dimension of ground truth motion featuremap is not normal distributed
# 190th dimension of ground truth motion featuremap is not normal distributed
# 191th dimension of ground truth motion featuremap is not normal distributed
# 192th dimension of ground truth motion featuremap is not normal distributed
# 193th dimension of ground truth motion featuremap is not normal distributed
# 194th dimension of ground truth motion featuremap is not normal distributed
# 195th dimension of ground truth motion featuremap is not normal distributed
# 196th dimension of ground truth motion featuremap is not normal distributed
# 197th dimension of ground truth motion featuremap is not normal distributed
# 198th dimension of ground truth motion featuremap is not normal distributed
# 199th dimension of ground truth motion featuremap is not normal distributed
# 200th dimension of ground truth motion featuremap is not normal distributed
# 201th dimension of ground truth motion featuremap is not normal distributed
# 202th dimension of ground truth motion featuremap is not normal distributed
# 203th dimension of ground truth motion featuremap is not normal distributed
# 204th dimension of ground truth motion featuremap is not normal distributed
# 205th dimension of ground truth motion featuremap is not normal distributed
# 206th dimension of ground truth motion featuremap is not normal distributed
# 207th dimension of ground truth motion featuremap is not normal distributed
# 208th dimension of ground truth motion featuremap is not normal distributed
# 209th dimension of ground truth motion featuremap is not normal distributed
# 210th dimension of ground truth motion featuremap is not normal distributed
# 211th dimension of ground truth motion featuremap is not normal distributed
# 212th dimension of ground truth motion featuremap is not normal distributed
# 213th dimension of ground truth motion featuremap is not normal distributed
# 214th dimension of ground truth motion featuremap is not normal distributed
# 215th dimension of ground truth motion featuremap is not normal distributed
# 216th dimension of ground truth motion featuremap is not normal distributed
# 217th dimension of ground truth motion featuremap is not normal distributed
# 218th dimension of ground truth motion featuremap is not normal distributed
# 219th dimension of ground truth motion featuremap is not normal distributed
# 220th dimension of ground truth motion featuremap is not normal distributed
# 221th dimension of ground truth motion featuremap is not normal distributed
# 222th dimension of ground truth motion featuremap is not normal distributed
# 223th dimension of ground truth motion featuremap is not normal distributed
# 224th dimension of ground truth motion featuremap is not normal distributed
# 225th dimension of ground truth motion featuremap is not normal distributed
# 226th dimension of ground truth motion featuremap is not normal distributed
# 227th dimension of ground truth motion featuremap is not normal distributed
# 228th dimension of ground truth motion featuremap is not normal distributed
# 229th dimension of ground truth motion featuremap is not normal distributed
# 230th dimension of ground truth motion featuremap is not normal distributed
# 231th dimension of ground truth motion featuremap is not normal distributed
# 232th dimension of ground truth motion featuremap is not normal distributed
# 233th dimension of ground truth motion featuremap is not normal distributed
# 234th dimension of ground truth motion featuremap is not normal distributed
# 235th dimension of ground truth motion featuremap is not normal distributed
# 236th dimension of ground truth motion featuremap is not normal distributed
# 237th dimension of ground truth motion featuremap is not normal distributed
# 238th dimension of ground truth motion featuremap is not normal distributed
# 239th dimension of ground truth motion featuremap is not normal distributed
# 240th dimension of ground truth motion featuremap is not normal distributed
# 241th dimension of ground truth motion featuremap is not normal distributed
# 242th dimension of ground truth motion featuremap is not normal distributed
# 243th dimension of ground truth motion featuremap is not normal distributed
# 244th dimension of ground truth motion featuremap is not normal distributed
# 245th dimension of ground truth motion featuremap is not normal distributed
# 246th dimension of ground truth motion featuremap is not normal distributed
# 247th dimension of ground truth motion featuremap is not normal distributed
# 248th dimension of ground truth motion featuremap is not normal distributed
# 249th dimension of ground truth motion featuremap is not normal distributed
# 250th dimension of ground truth motion featuremap is not normal distributed
# 251th dimension of ground truth motion featuremap is not normal distributed
# 252th dimension of ground truth motion featuremap is not normal distributed
# 253th dimension of ground truth motion featuremap is not normal distributed
# 254th dimension of ground truth motion featuremap is not normal distributed
# 255th dimension of ground truth motion featuremap is not normal distributed
# 256th dimension of ground truth motion featuremap is not normal distributed
# 257th dimension of ground truth motion featuremap is not normal distributed
# 258th dimension of ground truth motion featuremap is not normal distributed
# 259th dimension of ground truth motion featuremap is not normal distributed
# 260th dimension of ground truth motion featuremap is not normal distributed
# 261th dimension of ground truth motion featuremap is not normal distributed
# 262th dimension of ground truth motion featuremap is not normal distributed
# 263th dimension of ground truth motion featuremap is not normal distributed
# 264th dimension of ground truth motion featuremap is not normal distributed
# 265th dimension of ground truth motion featuremap is not normal distributed
# 266th dimension of ground truth motion featuremap is not normal distributed
# 267th dimension of ground truth motion featuremap is not normal distributed
# 268th dimension of ground truth motion featuremap is not normal distributed
# 269th dimension of ground truth motion featuremap is not normal distributed
# 270th dimension of ground truth motion featuremap is not normal distributed
# 271th dimension of ground truth motion featuremap is not normal distributed
# 272th dimension of ground truth motion featuremap is not normal distributed
# 273th dimension of ground truth motion featuremap is not normal distributed
# 274th dimension of ground truth motion featuremap is not normal distributed
# 275th dimension of ground truth motion featuremap is not normal distributed
# 276th dimension of ground truth motion featuremap is not normal distributed
# 277th dimension of ground truth motion featuremap is not normal distributed
# 278th dimension of ground truth motion featuremap is not normal distributed
# 279th dimension of ground truth motion featuremap is not normal distributed
# 280th dimension of ground truth motion featuremap is not normal distributed
# 281th dimension of ground truth motion featuremap is not normal distributed
# 282th dimension of ground truth motion featuremap is not normal distributed
# 283th dimension of ground truth motion featuremap is not normal distributed
# 284th dimension of ground truth motion featuremap is not normal distributed
# 285th dimension of ground truth motion featuremap is not normal distributed
# 286th dimension of ground truth motion featuremap is not normal distributed
# 287th dimension of ground truth motion featuremap is not normal distributed
# 288th dimension of ground truth motion featuremap is not normal distributed
# 289th dimension of ground truth motion featuremap is not normal distributed
# 290th dimension of ground truth motion featuremap is not normal distributed
# 291th dimension of ground truth motion featuremap is not normal distributed
# 292th dimension of ground truth motion featuremap is not normal distributed
# 293th dimension of ground truth motion featuremap is not normal distributed
# 294th dimension of ground truth motion featuremap is not normal distributed
# 295th dimension of ground truth motion featuremap is not normal distributed
# 296th dimension of ground truth motion featuremap is not normal distributed
# 297th dimension of ground truth motion featuremap is not normal distributed
# 298th dimension of ground truth motion featuremap is not normal distributed
# 299th dimension of ground truth motion featuremap is not normal distributed
# 300th dimension of ground truth motion featuremap is not normal distributed
# 301th dimension of ground truth motion featuremap is not normal distributed
# 302th dimension of ground truth motion featuremap is not normal distributed
# 303th dimension of ground truth motion featuremap is not normal distributed
# 304th dimension of ground truth motion featuremap is not normal distributed
# 305th dimension of ground truth motion featuremap is not normal distributed
# 306th dimension of ground truth motion featuremap is not normal distributed
# 307th dimension of ground truth motion featuremap is not normal distributed
# 308th dimension of ground truth motion featuremap is not normal distributed
# 309th dimension of ground truth motion featuremap is not normal distributed
# 310th dimension of ground truth motion featuremap is not normal distributed
# 311th dimension of ground truth motion featuremap is not normal distributed
# 312th dimension of ground truth motion featuremap is not normal distributed
# 313th dimension of ground truth motion featuremap is not normal distributed
# 314th dimension of ground truth motion featuremap is not normal distributed
# 315th dimension of ground truth motion featuremap is not normal distributed
# 316th dimension of ground truth motion featuremap is not normal distributed
# 317th dimension of ground truth motion featuremap is not normal distributed
# 318th dimension of ground truth motion featuremap is not normal distributed
# 319th dimension of ground truth motion featuremap is not normal distributed
# 320th dimension of ground truth motion featuremap is not normal distributed
# 321th dimension of ground truth motion featuremap is not normal distributed
# 322th dimension of ground truth motion featuremap is not normal distributed
# 323th dimension of ground truth motion featuremap is not normal distributed
# 324th dimension of ground truth motion featuremap is not normal distributed
# 325th dimension of ground truth motion featuremap is not normal distributed
# 326th dimension of ground truth motion featuremap is not normal distributed
# 327th dimension of ground truth motion featuremap is not normal distributed
# 328th dimension of ground truth motion featuremap is not normal distributed
# 329th dimension of ground truth motion featuremap is not normal distributed
# 330th dimension of ground truth motion featuremap is not normal distributed
# 331th dimension of ground truth motion featuremap is not normal distributed
# 332th dimension of ground truth motion featuremap is not normal distributed
# 333th dimension of ground truth motion featuremap is not normal distributed
# 334th dimension of ground truth motion featuremap is not normal distributed
# 335th dimension of ground truth motion featuremap is not normal distributed
# 336th dimension of ground truth motion featuremap is not normal distributed
# 337th dimension of ground truth motion featuremap is not normal distributed
# 338th dimension of ground truth motion featuremap is not normal distributed
# 339th dimension of ground truth motion featuremap is not normal distributed
# 340th dimension of ground truth motion featuremap is not normal distributed
# 341th dimension of ground truth motion featuremap is not normal distributed
# 342th dimension of ground truth motion featuremap is not normal distributed
# 343th dimension of ground truth motion featuremap is not normal distributed
# 344th dimension of ground truth motion featuremap is not normal distributed
# 345th dimension of ground truth motion featuremap is not normal distributed
# 346th dimension of ground truth motion featuremap is not normal distributed
# 347th dimension of ground truth motion featuremap is not normal distributed
# 348th dimension of ground truth motion featuremap is not normal distributed
# 349th dimension of ground truth motion featuremap is not normal distributed
# 350th dimension of ground truth motion featuremap is not normal distributed
# 351th dimension of ground truth motion featuremap is not normal distributed
# 352th dimension of ground truth motion featuremap is not normal distributed
# 353th dimension of ground truth motion featuremap is not normal distributed
# 354th dimension of ground truth motion featuremap is not normal distributed
# 355th dimension of ground truth motion featuremap is not normal distributed
# 356th dimension of ground truth motion featuremap is not normal distributed
# 357th dimension of ground truth motion featuremap is not normal distributed
# 358th dimension of ground truth motion featuremap is not normal distributed
# 359th dimension of ground truth motion featuremap is not normal distributed
# 360th dimension of ground truth motion featuremap is not normal distributed
# 361th dimension of ground truth motion featuremap is not normal distributed
# 362th dimension of ground truth motion featuremap is not normal distributed
# 363th dimension of ground truth motion featuremap is not normal distributed
# 364th dimension of ground truth motion featuremap is not normal distributed
# 365th dimension of ground truth motion featuremap is not normal distributed
# 366th dimension of ground truth motion featuremap is not normal distributed
# 367th dimension of ground truth motion featuremap is not normal distributed
# 368th dimension of ground truth motion featuremap is not normal distributed
# 369th dimension of ground truth motion featuremap is not normal distributed
# 370th dimension of ground truth motion featuremap is not normal distributed
# 371th dimension of ground truth motion featuremap is not normal distributed
# 372th dimension of ground truth motion featuremap is not normal distributed
# 373th dimension of ground truth motion featuremap is not normal distributed
# 374th dimension of ground truth motion featuremap is not normal distributed
# 375th dimension of ground truth motion featuremap is not normal distributed
# 376th dimension of ground truth motion featuremap is not normal distributed
# 377th dimension of ground truth motion featuremap is not normal distributed
# 378th dimension of ground truth motion featuremap is not normal distributed
# 379th dimension of ground truth motion featuremap is not normal distributed
# 380th dimension of ground truth motion featuremap is not normal distributed
# 381th dimension of ground truth motion featuremap is not normal distributed
# 382th dimension of ground truth motion featuremap is not normal distributed
# 383th dimension of ground truth motion featuremap is not normal distributed
# 384th dimension of ground truth motion featuremap is not normal distributed
# 385th dimension of ground truth motion featuremap is not normal distributed
# 386th dimension of ground truth motion featuremap is not normal distributed
# 387th dimension of ground truth motion featuremap is not normal distributed
# 388th dimension of ground truth motion featuremap is not normal distributed
# 389th dimension of ground truth motion featuremap is not normal distributed
# 390th dimension of ground truth motion featuremap is not normal distributed
# 391th dimension of ground truth motion featuremap is not normal distributed
# 392th dimension of ground truth motion featuremap is not normal distributed
# 393th dimension of ground truth motion featuremap is not normal distributed
# 394th dimension of ground truth motion featuremap is not normal distributed
# 395th dimension of ground truth motion featuremap is not normal distributed
# 396th dimension of ground truth motion featuremap is not normal distributed
# 397th dimension of ground truth motion featuremap is not normal distributed
# 398th dimension of ground truth motion featuremap is not normal distributed
# 399th dimension of ground truth motion featuremap is not normal distributed
# 400th dimension of ground truth motion featuremap is not normal distributed
# 401th dimension of ground truth motion featuremap is not normal distributed
# 402th dimension of ground truth motion featuremap is not normal distributed
# 403th dimension of ground truth motion featuremap is not normal distributed
# 404th dimension of ground truth motion featuremap is not normal distributed
# 405th dimension of ground truth motion featuremap is not normal distributed
# 406th dimension of ground truth motion featuremap is not normal distributed
# 407th dimension of ground truth motion featuremap is not normal distributed
# 408th dimension of ground truth motion featuremap is not normal distributed
# 409th dimension of ground truth motion featuremap is not normal distributed
# 410th dimension of ground truth motion featuremap is not normal distributed
# 411th dimension of ground truth motion featuremap is not normal distributed
# 412th dimension of ground truth motion featuremap is not normal distributed
# 413th dimension of ground truth motion featuremap is not normal distributed
# 414th dimension of ground truth motion featuremap is not normal distributed
# 415th dimension of ground truth motion featuremap is not normal distributed
# 416th dimension of ground truth motion featuremap is not normal distributed
# 417th dimension of ground truth motion featuremap is not normal distributed
# 418th dimension of ground truth motion featuremap is not normal distributed
# 419th dimension of ground truth motion featuremap is not normal distributed
# 420th dimension of ground truth motion featuremap is not normal distributed
# 421th dimension of ground truth motion featuremap is not normal distributed
# 422th dimension of ground truth motion featuremap is not normal distributed
# 423th dimension of ground truth motion featuremap is not normal distributed
# 424th dimension of ground truth motion featuremap is not normal distributed
# 425th dimension of ground truth motion featuremap is not normal distributed
# 426th dimension of ground truth motion featuremap is not normal distributed
# 427th dimension of ground truth motion featuremap is not normal distributed
# 428th dimension of ground truth motion featuremap is not normal distributed
# 429th dimension of ground truth motion featuremap is not normal distributed
# 430th dimension of ground truth motion featuremap is not normal distributed
# 431th dimension of ground truth motion featuremap is not normal distributed
# 432th dimension of ground truth motion featuremap is not normal distributed
# 433th dimension of ground truth motion featuremap is not normal distributed
# 434th dimension of ground truth motion featuremap is not normal distributed
# 435th dimension of ground truth motion featuremap is not normal distributed
# 436th dimension of ground truth motion featuremap is not normal distributed
# 437th dimension of ground truth motion featuremap is not normal distributed
# 438th dimension of ground truth motion featuremap is not normal distributed
# 439th dimension of ground truth motion featuremap is not normal distributed
# 440th dimension of ground truth motion featuremap is not normal distributed
# 441th dimension of ground truth motion featuremap is not normal distributed
# 442th dimension of ground truth motion featuremap is not normal distributed
# 443th dimension of ground truth motion featuremap is not normal distributed
# 444th dimension of ground truth motion featuremap is not normal distributed
# 445th dimension of ground truth motion featuremap is not normal distributed
# 446th dimension of ground truth motion featuremap is not normal distributed
# 447th dimension of ground truth motion featuremap is not normal distributed
# 448th dimension of ground truth motion featuremap is not normal distributed
# 449th dimension of ground truth motion featuremap is not normal distributed
# 450th dimension of ground truth motion featuremap is not normal distributed
# 451th dimension of ground truth motion featuremap is not normal distributed
# 452th dimension of ground truth motion featuremap is not normal distributed
# 453th dimension of ground truth motion featuremap is not normal distributed
# 454th dimension of ground truth motion featuremap is not normal distributed
# 455th dimension of ground truth motion featuremap is not normal distributed
# 456th dimension of ground truth motion featuremap is not normal distributed
# 457th dimension of ground truth motion featuremap is not normal distributed
# 458th dimension of ground truth motion featuremap is not normal distributed
# 459th dimension of ground truth motion featuremap is not normal distributed
# 460th dimension of ground truth motion featuremap is not normal distributed
# 461th dimension of ground truth motion featuremap is not normal distributed
# 462th dimension of ground truth motion featuremap is not normal distributed
# 463th dimension of ground truth motion featuremap is not normal distributed
# 464th dimension of ground truth motion featuremap is not normal distributed
# 465th dimension of ground truth motion featuremap is not normal distributed
# 466th dimension of ground truth motion featuremap is not normal distributed
# 467th dimension of ground truth motion featuremap is not normal distributed
# 468th dimension of ground truth motion featuremap is not normal distributed
# 469th dimension of ground truth motion featuremap is not normal distributed
# 470th dimension of ground truth motion featuremap is not normal distributed
# 471th dimension of ground truth motion featuremap is not normal distributed
# 472th dimension of ground truth motion featuremap is not normal distributed
# 473th dimension of ground truth motion featuremap is not normal distributed
# 474th dimension of ground truth motion featuremap is not normal distributed
# 475th dimension of ground truth motion featuremap is not normal distributed
# 476th dimension of ground truth motion featuremap is not normal distributed
# 477th dimension of ground truth motion featuremap is not normal distributed
# 478th dimension of ground truth motion featuremap is not normal distributed
# 479th dimension of ground truth motion featuremap is not normal distributed
# 480th dimension of ground truth motion featuremap is not normal distributed
# 481th dimension of ground truth motion featuremap is not normal distributed
# 482th dimension of ground truth motion featuremap is not normal distributed
# 483th dimension of ground truth motion featuremap is not normal distributed
# 484th dimension of ground truth motion featuremap is not normal distributed
# 485th dimension of ground truth motion featuremap is not normal distributed
# 486th dimension of ground truth motion featuremap is not normal distributed
# 487th dimension of ground truth motion featuremap is not normal distributed
# 488th dimension of ground truth motion featuremap is not normal distributed
# 489th dimension of ground truth motion featuremap is not normal distributed
# 490th dimension of ground truth motion featuremap is not normal distributed
# 491th dimension of ground truth motion featuremap is not normal distributed
# 492th dimension of ground truth motion featuremap is not normal distributed
# 493th dimension of ground truth motion featuremap is not normal distributed
# 494th dimension of ground truth motion featuremap is not normal distributed
# 495th dimension of ground truth motion featuremap is not normal distributed
# 496th dimension of ground truth motion featuremap is not normal distributed
# 497th dimension of ground truth motion featuremap is not normal distributed
# 498th dimension of ground truth motion featuremap is not normal distributed
# 499th dimension of ground truth motion featuremap is not normal distributed
# 500th dimension of ground truth motion featuremap is not normal distributed
# 501th dimension of ground truth motion featuremap is not normal distributed
# 502th dimension of ground truth motion featuremap is not normal distributed
# 503th dimension of ground truth motion featuremap is not normal distributed
# 504th dimension of ground truth motion featuremap is not normal distributed
# 505th dimension of ground truth motion featuremap is not normal distributed
# 506th dimension of ground truth motion featuremap is not normal distributed
# 507th dimension of ground truth motion featuremap is not normal distributed
# 508th dimension of ground truth motion featuremap is not normal distributed
# 509th dimension of ground truth motion featuremap is not normal distributed
# 510th dimension of ground truth motion featuremap is not normal distributed
# 511th dimension of ground truth motion featuremap is not normal distributed
# 0th dimension of generated motion featuremap is not normal distributed
# 1th dimension of generated motion featuremap is not normal distributed
# 2th dimension of generated motion featuremap is not normal distributed
# 3th dimension of generated motion featuremap is not normal distributed
# 4th dimension of generated motion featuremap is not normal distributed
# 5th dimension of generated motion featuremap is not normal distributed
# 6th dimension of generated motion featuremap is not normal distributed
# 7th dimension of generated motion featuremap is not normal distributed
# 8th dimension of generated motion featuremap is not normal distributed
# 9th dimension of generated motion featuremap is not normal distributed
# 10th dimension of generated motion featuremap is not normal distributed
# 11th dimension of generated motion featuremap is not normal distributed
# 12th dimension of generated motion featuremap is not normal distributed
# 13th dimension of generated motion featuremap is not normal distributed
# 14th dimension of generated motion featuremap is not normal distributed
# 15th dimension of generated motion featuremap is not normal distributed
# 16th dimension of generated motion featuremap is not normal distributed
# 17th dimension of generated motion featuremap is not normal distributed
# 18th dimension of generated motion featuremap is not normal distributed
# 19th dimension of generated motion featuremap is not normal distributed
# 20th dimension of generated motion featuremap is not normal distributed
# 21th dimension of generated motion featuremap is not normal distributed
# 22th dimension of generated motion featuremap is not normal distributed
# 23th dimension of generated motion featuremap is not normal distributed
# 24th dimension of generated motion featuremap is not normal distributed
# 25th dimension of generated motion featuremap is not normal distributed
# 26th dimension of generated motion featuremap is not normal distributed
# 27th dimension of generated motion featuremap is not normal distributed
# 28th dimension of generated motion featuremap is not normal distributed
# 29th dimension of generated motion featuremap is not normal distributed
# 30th dimension of generated motion featuremap is not normal distributed
# 31th dimension of generated motion featuremap is not normal distributed
# 32th dimension of generated motion featuremap is not normal distributed
# 33th dimension of generated motion featuremap is not normal distributed
# 34th dimension of generated motion featuremap is not normal distributed
# 35th dimension of generated motion featuremap is not normal distributed
# 36th dimension of generated motion featuremap is not normal distributed
# 37th dimension of generated motion featuremap is not normal distributed
# 38th dimension of generated motion featuremap is not normal distributed
# 39th dimension of generated motion featuremap is not normal distributed
# 40th dimension of generated motion featuremap is not normal distributed
# 41th dimension of generated motion featuremap is not normal distributed
# 42th dimension of generated motion featuremap is not normal distributed
# 43th dimension of generated motion featuremap is not normal distributed
# 44th dimension of generated motion featuremap is not normal distributed
# 45th dimension of generated motion featuremap is not normal distributed
# 46th dimension of generated motion featuremap is not normal distributed
# 47th dimension of generated motion featuremap is not normal distributed
# 48th dimension of generated motion featuremap is not normal distributed
# 49th dimension of generated motion featuremap is not normal distributed
# 50th dimension of generated motion featuremap is not normal distributed
# 51th dimension of generated motion featuremap is not normal distributed
# 52th dimension of generated motion featuremap is not normal distributed
# 53th dimension of generated motion featuremap is not normal distributed
# 54th dimension of generated motion featuremap is not normal distributed
# 55th dimension of generated motion featuremap is not normal distributed
# 56th dimension of generated motion featuremap is not normal distributed
# 57th dimension of generated motion featuremap is not normal distributed
# 58th dimension of generated motion featuremap is not normal distributed
# 59th dimension of generated motion featuremap is not normal distributed
# 60th dimension of generated motion featuremap is not normal distributed
# 61th dimension of generated motion featuremap is not normal distributed
# 62th dimension of generated motion featuremap is not normal distributed
# 63th dimension of generated motion featuremap is not normal distributed
# 64th dimension of generated motion featuremap is not normal distributed
# 65th dimension of generated motion featuremap is not normal distributed
# 66th dimension of generated motion featuremap is not normal distributed
# 67th dimension of generated motion featuremap is not normal distributed
# 68th dimension of generated motion featuremap is not normal distributed
# 69th dimension of generated motion featuremap is not normal distributed
# 70th dimension of generated motion featuremap is not normal distributed
# 71th dimension of generated motion featuremap is not normal distributed
# 72th dimension of generated motion featuremap is not normal distributed
# 73th dimension of generated motion featuremap is not normal distributed
# 74th dimension of generated motion featuremap is not normal distributed
# 75th dimension of generated motion featuremap is not normal distributed
# 76th dimension of generated motion featuremap is not normal distributed
# 77th dimension of generated motion featuremap is not normal distributed
# 78th dimension of generated motion featuremap is not normal distributed
# 79th dimension of generated motion featuremap is not normal distributed
# 80th dimension of generated motion featuremap is not normal distributed
# 81th dimension of generated motion featuremap is not normal distributed
# 82th dimension of generated motion featuremap is not normal distributed
# 83th dimension of generated motion featuremap is not normal distributed
# 84th dimension of generated motion featuremap is not normal distributed
# 85th dimension of generated motion featuremap is not normal distributed
# 86th dimension of generated motion featuremap is not normal distributed
# 87th dimension of generated motion featuremap is not normal distributed
# 88th dimension of generated motion featuremap is not normal distributed
# 89th dimension of generated motion featuremap is not normal distributed
# 90th dimension of generated motion featuremap is not normal distributed
# 91th dimension of generated motion featuremap is not normal distributed
# 92th dimension of generated motion featuremap is not normal distributed
# 93th dimension of generated motion featuremap is not normal distributed
# 94th dimension of generated motion featuremap is not normal distributed
# 95th dimension of generated motion featuremap is not normal distributed
# 96th dimension of generated motion featuremap is not normal distributed
# 97th dimension of generated motion featuremap is not normal distributed
# 98th dimension of generated motion featuremap is not normal distributed
# 99th dimension of generated motion featuremap is not normal distributed
# 100th dimension of generated motion featuremap is not normal distributed
# 101th dimension of generated motion featuremap is not normal distributed
# 102th dimension of generated motion featuremap is not normal distributed
# 103th dimension of generated motion featuremap is not normal distributed
# 104th dimension of generated motion featuremap is not normal distributed
# 105th dimension of generated motion featuremap is not normal distributed
# 106th dimension of generated motion featuremap is not normal distributed
# 107th dimension of generated motion featuremap is not normal distributed
# 108th dimension of generated motion featuremap is not normal distributed
# 109th dimension of generated motion featuremap is not normal distributed
# 110th dimension of generated motion featuremap is not normal distributed
# 111th dimension of generated motion featuremap is not normal distributed
# 112th dimension of generated motion featuremap is not normal distributed
# 113th dimension of generated motion featuremap is not normal distributed
# 114th dimension of generated motion featuremap is not normal distributed
# 115th dimension of generated motion featuremap is not normal distributed
# 116th dimension of generated motion featuremap is not normal distributed
# 117th dimension of generated motion featuremap is not normal distributed
# 118th dimension of generated motion featuremap is not normal distributed
# 119th dimension of generated motion featuremap is not normal distributed
# 120th dimension of generated motion featuremap is not normal distributed
# 121th dimension of generated motion featuremap is not normal distributed
# 122th dimension of generated motion featuremap is not normal distributed
# 123th dimension of generated motion featuremap is not normal distributed
# 124th dimension of generated motion featuremap is not normal distributed
# 125th dimension of generated motion featuremap is not normal distributed
# 126th dimension of generated motion featuremap is not normal distributed
# ...
# 293th dimension of generated motion featuremap is not normal distributed
# 294th dimension of generated motion featuremap is not normal distributed
# 295th dimension of generated motion featuremap is not normal distributed
# 296th dimension of generated motion featuremap is not normal distributed
# 297th dimension of generated motion featuremap is not normal distributed
# 298th dimension of generated motion featuremap is not normal distributed
# 299th dimension of generated motion featuremap is not normal distributed
# 300th dimension of generated motion featuremap is not normal distributed
# 301th dimension of generated motion featuremap is not normal distributed
# 302th dimension of generated motion featuremap is not normal distributed
# 303th dimension of generated motion featuremap is not normal distributed
# 304th dimension of generated motion featuremap is not normal distributed
# 305th dimension of generated motion featuremap is not normal distributed
# 306th dimension of generated motion featuremap is not normal distributed
# 307th dimension of generated motion featuremap is not normal distributed
# 308th dimension of generated motion featuremap is not normal distributed
# 309th dimension of generated motion featuremap is not normal distributed
# 310th dimension of generated motion featuremap is not normal distributed
# 311th dimension of generated motion featuremap is not normal distributed
# 312th dimension of generated motion featuremap is not normal distributed
# 313th dimension of generated motion featuremap is not normal distributed
# 314th dimension of generated motion featuremap is not normal distributed
# 315th dimension of generated motion featuremap is not normal distributed
# 316th dimension of generated motion featuremap is not normal distributed
# 317th dimension of generated motion featuremap is not normal distributed
# 318th dimension of generated motion featuremap is not normal distributed
# 319th dimension of generated motion featuremap is not normal distributed
# 320th dimension of generated motion featuremap is not normal distributed
# 321th dimension of generated motion featuremap is not normal distributed
# 322th dimension of generated motion featuremap is not normal distributed
# 323th dimension of generated motion featuremap is not normal distributed
# 324th dimension of generated motion featuremap is not normal distributed
# 325th dimension of generated motion featuremap is not normal distributed
# 326th dimension of generated motion featuremap is not normal distributed
# 327th dimension of generated motion featuremap is not normal distributed
# 328th dimension of generated motion featuremap is not normal distributed
# 329th dimension of generated motion featuremap is not normal distributed
# 330th dimension of generated motion featuremap is not normal distributed
# 331th dimension of generated motion featuremap is not normal distributed
# 332th dimension of generated motion featuremap is not normal distributed
# 333th dimension of generated motion featuremap is not normal distributed
# 334th dimension of generated motion featuremap is not normal distributed
# 335th dimension of generated motion featuremap is not normal distributed
# 336th dimension of generated motion featuremap is not normal distributed
# 337th dimension of generated motion featuremap is not normal distributed
# 338th dimension of generated motion featuremap is not normal distributed
# 339th dimension of generated motion featuremap is not normal distributed
# 340th dimension of generated motion featuremap is not normal distributed
# 341th dimension of generated motion featuremap is not normal distributed
# 342th dimension of generated motion featuremap is not normal distributed
# 343th dimension of generated motion featuremap is not normal distributed
# 344th dimension of generated motion featuremap is not normal distributed
# 345th dimension of generated motion featuremap is not normal distributed
# 346th dimension of generated motion featuremap is not normal distributed
# 347th dimension of generated motion featuremap is not normal distributed
# 348th dimension of generated motion featuremap is not normal distributed
# 349th dimension of generated motion featuremap is not normal distributed
# 350th dimension of generated motion featuremap is not normal distributed
# 351th dimension of generated motion featuremap is not normal distributed
# 352th dimension of generated motion featuremap is not normal distributed
# 353th dimension of generated motion featuremap is not normal distributed
# 354th dimension of generated motion featuremap is not normal distributed
# 355th dimension of generated motion featuremap is not normal distributed
# 356th dimension of generated motion featuremap is not normal distributed
# 357th dimension of generated motion featuremap is not normal distributed
# 358th dimension of generated motion featuremap is not normal distributed
# 359th dimension of generated motion featuremap is not normal distributed
# 360th dimension of generated motion featuremap is not normal distributed
# 361th dimension of generated motion featuremap is not normal distributed
# 362th dimension of generated motion featuremap is not normal distributed
# 363th dimension of generated motion featuremap is not normal distributed
# 364th dimension of generated motion featuremap is not normal distributed
# 365th dimension of generated motion featuremap is not normal distributed
# 366th dimension of generated motion featuremap is not normal distributed
# 367th dimension of generated motion featuremap is not normal distributed
# 368th dimension of generated motion featuremap is not normal distributed
# 369th dimension of generated motion featuremap is not normal distributed
# 370th dimension of generated motion featuremap is not normal distributed
# 371th dimension of generated motion featuremap is not normal distributed
# 372th dimension of generated motion featuremap is not normal distributed
# 373th dimension of generated motion featuremap is not normal distributed
# 374th dimension of generated motion featuremap is not normal distributed
# 375th dimension of generated motion featuremap is not normal distributed
# 376th dimension of generated motion featuremap is not normal distributed
# 377th dimension of generated motion featuremap is not normal distributed
# 378th dimension of generated motion featuremap is not normal distributed
# 379th dimension of generated motion featuremap is not normal distributed
# 380th dimension of generated motion featuremap is not normal distributed
# 381th dimension of generated motion featuremap is not normal distributed
# 382th dimension of generated motion featuremap is not normal distributed
# 383th dimension of generated motion featuremap is not normal distributed
# 384th dimension of generated motion featuremap is not normal distributed
# 385th dimension of generated motion featuremap is not normal distributed
# 386th dimension of generated motion featuremap is not normal distributed
# 387th dimension of generated motion featuremap is not normal distributed
# 388th dimension of generated motion featuremap is not normal distributed
# 389th dimension of generated motion featuremap is not normal distributed
# 390th dimension of generated motion featuremap is not normal distributed
# 391th dimension of generated motion featuremap is not normal distributed
# 392th dimension of generated motion featuremap is not normal distributed
# 393th dimension of generated motion featuremap is not normal distributed
# 394th dimension of generated motion featuremap is not normal distributed
# 395th dimension of generated motion featuremap is not normal distributed
# 396th dimension of generated motion featuremap is not normal distributed
# 397th dimension of generated motion featuremap is not normal distributed
# 398th dimension of generated motion featuremap is not normal distributed
# 399th dimension of generated motion featuremap is not normal distributed
# 400th dimension of generated motion featuremap is not normal distributed
# 401th dimension of generated motion featuremap is not normal distributed
# 402th dimension of generated motion featuremap is not normal distributed
# 403th dimension of generated motion featuremap is not normal distributed
# 404th dimension of generated motion featuremap is not normal distributed
# 405th dimension of generated motion featuremap is not normal distributed
# 406th dimension of generated motion featuremap is not normal distributed
# 407th dimension of generated motion featuremap is not normal distributed
# 408th dimension of generated motion featuremap is not normal distributed
# 409th dimension of generated motion featuremap is not normal distributed
# 410th dimension of generated motion featuremap is not normal distributed
# 411th dimension of generated motion featuremap is not normal distributed
# 412th dimension of generated motion featuremap is not normal distributed
# 413th dimension of generated motion featuremap is not normal distributed
# 414th dimension of generated motion featuremap is not normal distributed
# 415th dimension of generated motion featuremap is not normal distributed
# 416th dimension of generated motion featuremap is not normal distributed
# 417th dimension of generated motion featuremap is not normal distributed
# 418th dimension of generated motion featuremap is not normal distributed
# 419th dimension of generated motion featuremap is not normal distributed
# 420th dimension of generated motion featuremap is not normal distributed
# 421th dimension of generated motion featuremap is not normal distributed
# 422th dimension of generated motion featuremap is not normal distributed
# 423th dimension of generated motion featuremap is not normal distributed
# 424th dimension of generated motion featuremap is not normal distributed
# 425th dimension of generated motion featuremap is not normal distributed
# 426th dimension of generated motion featuremap is not normal distributed
# 427th dimension of generated motion featuremap is not normal distributed
# 428th dimension of generated motion featuremap is not normal distributed
# 429th dimension of generated motion featuremap is not normal distributed
# 430th dimension of generated motion featuremap is not normal distributed
# 431th dimension of generated motion featuremap is not normal distributed
# 432th dimension of generated motion featuremap is not normal distributed
# 433th dimension of generated motion featuremap is not normal distributed
# 434th dimension of generated motion featuremap is not normal distributed
# 435th dimension of generated motion featuremap is not normal distributed
# 436th dimension of generated motion featuremap is not normal distributed
# 437th dimension of generated motion featuremap is not normal distributed
# 438th dimension of generated motion featuremap is not normal distributed
# 439th dimension of generated motion featuremap is not normal distributed
# 440th dimension of generated motion featuremap is not normal distributed
# 441th dimension of generated motion featuremap is not normal distributed
# 442th dimension of generated motion featuremap is not normal distributed
# 443th dimension of generated motion featuremap is not normal distributed
# 444th dimension of generated motion featuremap is not normal distributed
# 445th dimension of generated motion featuremap is not normal distributed
# 446th dimension of generated motion featuremap is not normal distributed
# 447th dimension of generated motion featuremap is not normal distributed
# 448th dimension of generated motion featuremap is not normal distributed
# 449th dimension of generated motion featuremap is not normal distributed
# 450th dimension of generated motion featuremap is not normal distributed
# 451th dimension of generated motion featuremap is not normal distributed
# 452th dimension of generated motion featuremap is not normal distributed
# 453th dimension of generated motion featuremap is not normal distributed
# 454th dimension of generated motion featuremap is not normal distributed
# 455th dimension of generated motion featuremap is not normal distributed
# 456th dimension of generated motion featuremap is not normal distributed
# 457th dimension of generated motion featuremap is not normal distributed
# 458th dimension of generated motion featuremap is not normal distributed
# 459th dimension of generated motion featuremap is not normal distributed
# 460th dimension of generated motion featuremap is not normal distributed
# 461th dimension of generated motion featuremap is not normal distributed
# 462th dimension of generated motion featuremap is not normal distributed
# 463th dimension of generated motion featuremap is not normal distributed
# 464th dimension of generated motion featuremap is not normal distributed
# 465th dimension of generated motion featuremap is not normal distributed
# 466th dimension of generated motion featuremap is not normal distributed
# 467th dimension of generated motion featuremap is not normal distributed
# 468th dimension of generated motion featuremap is not normal distributed
# 469th dimension of generated motion featuremap is not normal distributed
# 470th dimension of generated motion featuremap is not normal distributed
# 471th dimension of generated motion featuremap is not normal distributed
# 472th dimension of generated motion featuremap is not normal distributed
# 473th dimension of generated motion featuremap is not normal distributed
# 474th dimension of generated motion featuremap is not normal distributed
# 475th dimension of generated motion featuremap is not normal distributed
# 476th dimension of generated motion featuremap is not normal distributed
# 477th dimension of generated motion featuremap is not normal distributed
# 478th dimension of generated motion featuremap is not normal distributed
# 479th dimension of generated motion featuremap is not normal distributed
# 480th dimension of generated motion featuremap is not normal distributed
# 481th dimension of generated motion featuremap is not normal distributed
# 482th dimension of generated motion featuremap is not normal distributed
# 483th dimension of generated motion featuremap is not normal distributed
# 484th dimension of generated motion featuremap is not normal distributed
# 485th dimension of generated motion featuremap is not normal distributed
# 486th dimension of generated motion featuremap is not normal distributed
# 487th dimension of generated motion featuremap is not normal distributed
# 488th dimension of generated motion featuremap is not normal distributed
# 489th dimension of generated motion featuremap is not normal distributed
# 490th dimension of generated motion featuremap is not normal distributed
# 491th dimension of generated motion featuremap is not normal distributed
# 492th dimension of generated motion featuremap is not normal distributed
# 493th dimension of generated motion featuremap is not normal distributed
# 494th dimension of generated motion featuremap is not normal distributed
# 495th dimension of generated motion featuremap is not normal distributed
# 496th dimension of generated motion featuremap is not normal distributed
# 497th dimension of generated motion featuremap is not normal distributed
# 498th dimension of generated motion featuremap is not normal distributed
# 499th dimension of generated motion featuremap is not normal distributed
# 500th dimension of generated motion featuremap is not normal distributed
# 501th dimension of generated motion featuremap is not normal distributed
# 502th dimension of generated motion featuremap is not normal distributed
# 503th dimension of generated motion featuremap is not normal distributed
# 504th dimension of generated motion featuremap is not normal distributed
# 505th dimension of generated motion featuremap is not normal distributed
# 506th dimension of generated motion featuremap is not normal distributed
# 507th dimension of generated motion featuremap is not normal distributed
# 508th dimension of generated motion featuremap is not normal distributed
# 509th dimension of generated motion featuremap is not normal distributed
# 510th dimension of generated motion featuremap is not normal distributed
# 511th dimension of generated motion featuremap is not normal distributed

# %%
# Kolmogorov-Smirnov test
# null hypothesis: the two distributions are identical(default, two-sided)
# tests are valid only for continuous distributions
### if p-value < 0.05, the distribution is not identical to a normal distribution

from scipy.stats import kstest
normal_dist = np.random.randn(1000)
print(kstest(real_safe[:, 0],"norm"))   # here we use the first dimension of feature map for demonstration, should change it to all dimension
print(kstest(fake_safe[:, 0],"norm"))
# Out:
# KstestResult(statistic=0.6861443923701361, pvalue=0.0)
# KstestResult(statistic=0.6859763663139373, pvalue=0.0)

# %%
# D’Agostino and Pearson’s
# null hypothesis: a sample comes from a normal distribution
### if p-value < 0.05, the distribution is not identical to a normal distribution

from scipy.stats import normaltest
normaltest(real_safe[:, 0])     # here we use the first dimension of feature map for demonstration, should change it to all dimension
# Out:
# NormaltestResult(statistic=77.35475674686636, pvalue=1.5945127560472322e-17)

# %% [markdown]
# ### Illustrative Test

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for i in range(5):      # we illustrate the first 5 dimensions of feature map to see if they are normal distributed
    x = real_safe[:, i]
    sns.kdeplot(x, shade=False)

# %%
# probplot, PP plot 
### The PP plot of read data should be similar to that of ideal normal distribution

import numpy as np 
import pylab 
import scipy.stats as stats

data_normal = np.random.normal(loc = 20, scale = 5, size=100)      # ideal normal distribution
data_real = real_safe[:, i]      # real distribution
data_uni = np.random.rand(200)      # uniform distribution

plt.figure(figsize=(12, 4))

ax1 = plt.subplot(1, 3, 1)
stats.probplot(data_normal, dist="norm", plot=pylab)
ax1.set_title("Normal Distribution")

ax2 = plt.subplot(1, 3, 2)
stats.probplot(data_uni, dist="norm", plot=pylab)
ax2.set_title("Uniform Distribution")

ax3 = plt.subplot(1, 3, 3)
stats.probplot(data_real, dist="norm", plot=pylab)
ax3.set_title("Real Distribution")

pylab.show()

# %%
# qqplot
# not that ppplot and qqplot are different
### The QQ plot of read data should be similar to that of ideal normal distribution

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.graphics.api import qqplot
 
sns.set_theme()
# %config InlineBackend.figure_format = 'retina'
 
mu, sigma = 0, 1
data_normal = np.random.normal(mu, sigma, 200)
data_uni = np.random.rand(200)
data_real = real_safe[:, i]

fig = plt.figure(figsize=(12, 4))
ax1 = fig.add_subplot(131)
fig = qqplot(data_normal, line="q", ax=ax1, fit=True)
ax1.set_title("Normal distribution")

ax2 = fig.add_subplot(132)
fig = qqplot(data_uni, line="q", ax=ax2, fit=True)
ax2.set_title("Uniform distribution")

ax3 = fig.add_subplot(133)
fig = qqplot(data_real, line="q", ax=ax3, fit=True)
ax3.set_title("Real distribution")

plt.show()

# %% [markdown]
# ### Calculate the FID score

# %%
real = real_safe
fake = fake_safe

n1 = fake.shape[0]
n2 = real.shape[0]

mean_fake = np.mean(real, axis=0)[None, ...]
mean_real = np.mean(fake, axis=0)[None, ...]

cov_fake_sum = fake.T @ fake - n1 * mean_fake.T @ mean_fake
cov_real_sum = real.T @ real - n2 * mean_real.T @ mean_real

cov_fake = cov_fake_sum / (n1 - 1)
cov_real = cov_real_sum / (n2 - 1)

# %%
mu1, mu2, sig1, sig2 = mean_fake, mean_real, cov_fake, cov_real
sig1sig2 = sig1 @ sig2

# %%
import torch

mu1_tensor = torch.tensor(mu1)
mu2_tensor = torch.tensor(mu2)
sig1_tensor = torch.tensor(sig1)
sig2_tensor = torch.tensor(sig2) 

a = (mu1_tensor - mu2_tensor).square().sum(dim=-1)
b = sig1_tensor.trace() + sig2_tensor.trace()
c = torch.linalg.eigvals(sig1_tensor @ sig2_tensor).sqrt().real.sum(dim=-1)

a + b - 2 * c
# Out:
# tensor([-0.5801])
